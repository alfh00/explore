# %%
import ccxt
import datetime

# %%
# Create a ccxt exchange object
exchange = ccxt.bitget()

# Specify the trading pair and timeframe
symbol = 'BTC/USDT'
timeframe = '1m'

# Calculate the start timestamp
start_date = datetime.datetime(2023, 8, 1)
start_timestamp = int(start_date.timestamp() * 1000)

# Fetch the OHLCV data
ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since=start_timestamp, limit=1000)

# Print the data
for candle in ohlcv:
    print(datetime.datetime.fromtimestamp(candle[0]/1000))

# %%
for candle in ohlcv:
    print(datetime.datetime.fromtimestamp(candle[0]/1000))

# %%
start_date1 = datetime.datetime(2023, 7, 5, 0, 0)

# %%
tms = int(start_date1.timestamp())
tms
# Out:
# 1688508000

# %%
exchange.fetch_ohlcv(symbol, timeframe, since=1688162400000, limit=1000)
# Out:
# [[1724998680000, 58910.67, 58910.67, 58896.16, 58896.16, 2.412066],
#  [1724998740000, 58896.16, 58913.88, 58879.5, 58894.92, 5.206773],
#  [1724998800000, 58894.92, 58937.09, 58887.01, 58934.15, 1.543318],
#  [1724998860000, 58934.15, 58938.0, 58912.5, 58926.69, 2.250969],
#  [1724998920000, 58926.69, 58944.71, 58924.28, 58924.33, 1.277892],
#  [1724998980000, 58924.33, 58924.33, 58924.32, 58924.32, 3.17041],
#  [1724999040000, 58924.32, 58924.33, 58924.29, 58924.3, 0.791173],
#  [1724999100000, 58924.3, 58924.32, 58924.29, 58924.32, 1.29726],
#  [1724999160000, 58924.32, 58944.66, 58924.31, 58938.75, 2.234252],
#  [1724999220000, 58938.75, 58938.76, 58924.3, 58924.31, 1.171304],
#  [1724999280000, 58924.31, 58924.31, 58914.49, 58914.49, 2.959582],
#  [1724999340000, 58914.49, 58914.49, 58913.05, 58913.1, 2.538078],
#  [1724999400000, 58913.1, 58929.57, 58892.03, 58892.04, 1.954121],
#  [1724999460000, 58892.04, 58932.92, 58892.03, 58931.91, 0.816792],
# ...

# %%
for candle in ohlcv:
    print(datetime.datetime.fromtimestamp(candle[0]/1000))
# Out:
# 2024-08-30 08:12:00
# 2024-08-30 08:13:00
# 2024-08-30 08:14:00
# 2024-08-30 08:15:00
# 2024-08-30 08:16:00
# 2024-08-30 08:17:00
# 2024-08-30 08:18:00
# 2024-08-30 08:19:00
# 2024-08-30 08:20:00
# 2024-08-30 08:21:00
# 2024-08-30 08:22:00
# 2024-08-30 08:23:00
# 2024-08-30 08:24:00
# 2024-08-30 08:25:00
# 2024-08-30 08:26:00
# 2024-08-30 08:27:00
# 2024-08-30 08:28:00
# 2024-08-30 08:29:00
# 2024-08-30 08:30:00
# 2024-08-30 08:31:00
# 2024-08-30 08:32:00
# 2024-08-30 08:33:00
# 2024-08-30 08:34:00
# 2024-08-30 08:35:00
# 2024-08-30 08:36:00
# 2024-08-30 08:37:00
# 2024-08-30 08:38:00
# 2024-08-30 08:39:00
# 2024-08-30 08:40:00
# 2024-08-30 08:41:00
# 2024-08-30 08:42:00
# 2024-08-30 08:43:00
# 2024-08-30 08:44:00
# 2024-08-30 08:45:00
# 2024-08-30 08:46:00
# 2024-08-30 08:47:00
# 2024-08-30 08:48:00
# 2024-08-30 08:49:00
# 2024-08-30 08:50:00
# 2024-08-30 08:51:00
# 2024-08-30 08:52:00
# 2024-08-30 08:53:00
# 2024-08-30 08:54:00
# 2024-08-30 08:55:00
# 2024-08-30 08:56:00
# ...
